# %%
#importing matplotlib
import matplotlib.pyplot as plt

# %%
x=range(10)

# %%
x
# Out:
# range(0, 10)

# %%
#we can also create two list
x1=[2,6,8,12]
y1=[3,7,13,20]

x2=[35,42,3,4]
y2=[8,45,34,2]

# %%
plt.xlabel('distance')  #x axis label
plt.ylabel('time')  #y axis label
plt.grid(c='green')  #to put grid lines
plt.plot(x1,y1,label="cars")

plt.plot(x2,y2,label="bikes")

plt.legend() #to show label of plot

# %% [markdown]
# #barplots#

# %%
plt.xlabel('time')
plt.ylabel('price')
plt.bar(x1,y1,label='apple',)
plt.plot(x1,y1,label='amazon')
plt.bar(x2,y2,label='microsoft')
plt.grid(c='red')
plt.legend()

# %%
players=["dhoni","sachin","virat"]
runs=[234,234,546]

# %%
plt.bar(players,runs)
plt.xlabel("players")
plt.ylabel("run")
plt.grid()

# %% [markdown]
# ##scatter

# %%
plt.scatter(x1,y1)
plt.scatter(x2,y2)
plt.grid(c='y')

# %%
plt.scatter(x1,y1,marker='*',s=100)#marker and size are optional
plt.scatter(x2,y2.marker='^',s=120)
plt.grid(c='y')
# Out:
#   File "<ipython-input-39-03c297ccdce3>", line 2
#     plt.scatter(x2,y2.marker='^',s=120)
#                   ^
# SyntaxError: keyword can't be an expression

# %%
plt.pie(players,runs)
plt.xlabel("players")
plt.ylabel("run")
plt.grid()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e08002ff87ca> in <module>()
# ----> 1 plt.pie(players,runs)
#       2 plt.xlabel("players")
#       3 plt.ylabel("run")
#       4 plt.grid()
#
# NameError: name 'plt' is not defined

# %%
x=[40,10]
y=[20,30]
plt.pie(x,y)
plt.
# Out:
# ([<matplotlib.patches.Wedge at 0x7f4892fdeef0>,
#   <matplotlib.patches.Wedge at 0x7f4892fec3c8>],
#  [Text(-17.070259045785065, 12.402268184077993, ''),
#   Text(25.160430065418396, -18.28011922617547, '')])
